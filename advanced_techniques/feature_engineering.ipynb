# %% [markdown]
# # Feature Selection & Engineering
# Learn how to reduce dimensionality and select the most important features.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load Data

# %%
data = fetch_california_housing()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %% [markdown]
# ## Univariate Feature Selection (SelectKBest)
# Selects the best features based on univariate statistical tests.

# %%
selector = SelectKBest(score_func=f_regression, k=4)
X_new = selector.fit_transform(X, y)
selected_features = X.columns[selector.get_support()]
print('Top 4 Features using SelectKBest:', list(selected_features))

# %% [markdown]
# ## Recursive Feature Elimination (RFE)
# Selects features by recursively considering smaller and smaller sets of features based on weights.

# %%
estimator = LinearRegression()
rfe = RFE(estimator, n_features_to_select=4, step=1)
rfe.fit(X, y)
rfe_features = X.columns[rfe.support_]
print('Top 4 Features using RFE:', list(rfe_features))
